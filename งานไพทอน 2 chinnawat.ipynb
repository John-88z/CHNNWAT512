# %% [markdown]
# 1.1

# %%
print("hello python")
# Out:
# hello python

# %% [markdown]
# 1.2

# %%
print("ChinnawatOotsa")
# Out:
# ChinnawatOotsa

# %% [markdown]
# 1.3

# %%
print(25+5)
x=25+5
print(x)
# Out:
# 30
# 30

# %% [markdown]
# 1.4

# %%
num= '3'+'4'
print(num)
# Out:
# 34

# %% [markdown]
# 1.5

# %%
hello="hi"
print(hello *3)
# Out:
# hihihi

# %% [markdown]
# 1.6

# %%
dog='box'
print(dog *5)
# Out:
# boxboxboxboxbox

# %% [markdown]
# 1.7

# %%
a,b,c=1.5,5, 'Superman'
print (type(a))
print (type(b))
print (type(c))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# 1.8

# %%
a = "1.265"
print (type(a))
a= int(1.265)
print (type(a))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# 1.9

# %%
a=3
b=3.5
c='PCC'
print('{} {} {}'.format(a,b,c))
print('{2} {1} {0}'.format(a,b,c))
# Out:
# 3 3.5 PCC
# PCC 3.5 3

# %% [markdown]
# 1.10

# %%
x=2.151617298
print('{0}'.format(x))
print('{:.2f}'.format(x))
# Out:
# 2.151617298
# 2.15

# %% [markdown]
# 1.11

# %%
x,y,z=25,'SUPER',160
print('name:' ,(y))
print('Age:' ,(x))
print('Height:' ,(z))
# Out:
# name: SUPER
# Age: 25
# Height: 160

# %% [markdown]
# 1.12

# %%
print('Scince',end='')
print('fair2017')
# Out:
# Scincefair2017

# %% [markdown]
# 1.13

# %%
area= 22/7*2**2
print('Area = {:.2f}'.format(area))
# Out:
# Area = 12.57

# %% [markdown]
# 1.14

# %%
a,b= 15,10
x=a**2 + b**2
print(x)
# Out:
# 325

# %% [markdown]
# 1.15

# %%
a,b,c=5,8,3/4
x=a**2 + b**2 -3/4**3
print(x)
# Out:
# 88.953125

# %% [markdown]
# 1.16

# %%
x=10
y=5
print(x>=10)
print(y>=10)
print(x>=10and y>=10)
# Out:
# True
# False
# False
